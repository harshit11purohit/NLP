# %%
import numpy as np
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer

nlp = spacy.load("en_core_web_sm")  
corpus = ["The dog runs fast",
          "A cat sleeps on the sofa",
          "Dogs and cats are great pets"]


sentence = "The cat runs fast"

vectorizer = TfidfVectorizer()
vectorizer.fit(corpus)


words = vectorizer.get_feature_names_out()
words_list = list(words)  

# calculates the TF-IDF scores specifically for your target sentence
tfidf_scores = vectorizer.transform([sentence]).toarray()[0]
print(words)
print(words_list)
# Out:
# ['and' 'are' 'cat' 'cats' 'dog' 'dogs' 'fast' 'great' 'on' 'pets' 'runs'
#  'sleeps' 'sofa' 'the']
# ['and', 'are', 'cat', 'cats', 'dog', 'dogs', 'fast', 'great', 'on', 'pets', 'runs', 'sleeps', 'sofa', 'the']

# %%
def tfidf_weighted_embedding(sentence):
    doc = nlp(sentence)
    word_embeddings = []
    weights = []

    for token in doc:
        word = token.text.lower()
        if word in words and token.has_vector:
            idx = list(words).index(word)
            word_embeddings.append(token.vector * tfidf_scores[idx])
            weights.append(tfidf_scores[idx])

    return np.sum(word_embeddings, axis=0) / np.sum(weights) if weights else np.zeros((nlp.vocab.vectors_length,))

embedding = tfidf_weighted_embedding(sentence)

print("Sentence Embedding (TF-IDF Weighted):", embedding[:5])  # Print first 5 values
# Out:
# Sentence Embedding (TF-IDF Weighted): [ 0.15215637  0.12443819 -0.59465979 -0.24738409 -0.03750529]

# %% [markdown]
# PCA

# %%
def average_embedding(sentence):
    doc = nlp(sentence)
    valid_vectors = [token.vector for token in doc if token.has_vector]
    return (
        np.mean(valid_vectors, axis=0)
        if valid_vectors
        else np.zeros((nlp.vocab.vectors_length,))
    )

# %%
from sklearn.decomposition import PCA

# Generate embeddings for all sentences in corpus
sentence_embeddings = np.array([average_embedding(sent) for sent in corpus])

# Apply PCA to reduce dimensions (e.g., from 300 to 50)
pca = PCA()
reduced_embeddings = pca.fit_transform(sentence_embeddings)

print("Reduced Sentence Embedding (PCA):", reduced_embeddings[0][:5])  # Print first 5 values
# Out:
# Reduced Sentence Embedding (PCA): [-1.2933475e+00 -1.3441613e+00 -1.5344074e-07]

# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.5.1-py3-none-any.whl.metadata (18 kB)
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-5.9.0-py3-none-any.whl.metadata (33 kB)
# Collecting huggingface-hub>=0.23.0 (from sentence-transformers)
#   Downloading huggingface_hub-1.15.0-py3-none-any.whl.metadata (14 kB)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Downloading torch-2.12.0-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from sentence-transformers) (2.4.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typer in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.25.1)
# Collecting safetensors>=0.4.3 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting filelock>=3.10.0 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Downloading filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Downloading fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Downloading hf_xet-1.5.0-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.13.0)
# Requirement already satisfied: certifi in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.15)
# Requirement already satisfied: h11>=0.16 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Collecting setuptools<82 (from torch>=1.11.0->sentence-transformers)
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.11.0->sentence-transformers)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from tqdm>=4.0.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.4.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jagdish singh\onedrive\desktop\nlp\nlp_env\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Downloading sentence_transformers-5.5.1-py3-none-any.whl (588 kB)
#    ---------------------------------------- 0.0/588.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/588.9 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/588.9 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/588.9 kB ? eta -:--:--
#    ---------------------------------------- 588.9/588.9 kB 957.1 kB/s  0:00:00
# Downloading transformers-5.9.0-py3-none-any.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.8 MB 2.6 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/10.8 MB 2.6 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/10.8 MB 2.8 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/10.8 MB 2.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/10.8 MB 2.9 MB/s eta 0:00:03
#    ------------- -------------------------- 3.7/10.8 MB 3.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.5/10.8 MB 3.1 MB/s eta 0:00:03
#    ------------------- -------------------- 5.2/10.8 MB 3.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.3/10.8 MB 3.3 MB/s eta 0:00:02
#    -------------------------- ------------- 7.1/10.8 MB 3.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.9/10.8 MB 3.4 MB/s eta 0:00:01
#    --------------------------------- ------ 8.9/10.8 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/10.8 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 3.6 MB/s  0:00:03
# Downloading huggingface_hub-1.15.0-py3-none-any.whl (663 kB)
#    ---------------------------------------- 0.0/663.6 kB ? eta -:--:--
#    ---------------------------------------- 663.6/663.6 kB 4.0 MB/s  0:00:00
# Downloading hf_xet-1.5.0-cp37-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.0 MB 4.0 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/4.0 MB 4.7 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 4.8 MB/s  0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --------------- ------------------------ 1.0/2.7 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.7 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 5.4 MB/s  0:00:00
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Downloading torch-2.12.0-cp313-cp313-win_amd64.whl (123.0 MB)
#    ---------------------------------------- 0.0/123.0 MB ? eta -:--:--
#    ----------------------------------------
1 MB/s eta 0:00:06
#    ---------------------------- ----------- 87.6/123.0 MB 7.1 MB/s eta 0:00:05
#    ----------------------------- ---------- 89.4/123.0 MB 7.2 MB/s eta 0:00:05
#    ----------------------------- ---------- 91.5/123.0 MB 7.2 MB/s eta 0:00:05
#    ------------------------------ --------- 93.8/123.0 MB 7.3 MB/s eta 0:00:05
#    ------------------------------- -------- 95.9/123.0 MB 7.3 MB/s eta 0:00:04
#    ------------------------------- -------- 98.3/123.0 MB 7.4 MB/s eta 0:00:04
#    -------------------------------- ------- 100.4/123.0 MB 7.4 MB/s eta 0:00:04
#    --------------------------------- ------ 103.0/123.0 MB 7.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 105.4/123.0 MB 7.5 MB/s eta 0:00:03
#    ----------------------------------- ---- 107.7/123.0 MB 7.6 MB/s eta 0:00:03
#    ----------------------------------- ---- 109.8/123.0 MB 7.6 MB/s eta 0:00:02
#    ------------------------------------ --- 112.5/123.0 MB 7.7 MB/s eta 0:00:02
#    ------------------------------------- -- 114.8/123.0 MB 7.7 MB/s eta 0:00:02
#    -------------------------------------- - 117.4/123.0 MB 7.8 MB/s eta 0:00:01
#    -------------------------------------- - 119.8/123.0 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------  122.4/123.0 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  122.9/123.0 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  122.9/123.0 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  122.9/123.0 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 123.0/123.0 MB 7.6 MB/s  0:00:16
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 7.2 MB/s  0:00:00
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------------------------- ---- 1.8/2.1 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 9.4 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    -------------- ------------------------- 2.4/6.3 MB 10.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.7/6.3 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 10.2 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 4.2 MB/s  0:00:00
# Installing collected packages: mpmath, sympy, setuptools, safetensors, networkx, hf-xet, fsspec, filelock, torch, huggingface-hub, tokenizers, transformers, sentence-transformers
#
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#   Attempting uninstall: setuptools
#    --- ------------------------------------  1/13 [sympy]
#     Found existing installation: setuptools 82.0.1
#    --- ------------------------------------  1/13 [sympy]
#    ------ ---------------------------------  2/13 [setuptools]
#    ------ ---------------------------------  2/13 [setuptools]
#    ------ ---------------------------------  2/13 [setuptools]
#    ------ ---------------------------------  2/13 [setuptools]
#     Uninstalling setuptools-82.0.1:
#    ------ ---------------------------------  2/13 [setuptools]
#    ------ ---------------------------------  2/13 [setuptools]
# ...
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    ------------ ---------------------------  4/13 [networkx]
#    --------------- ------------------------  5/13 [hf-xet]
#    --------------- ------------------------  5/13 [hf-xet]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    ------------------ ---------------------  6/13 [fsspec]
#    --------------------- ------------------  7/13 [filelock]
#    --------------------- ------------------  7/13 [filelock]
#    --------------------- ------------------  7/13 [filelock]
#    --------------------- ------------------  7/13 [filelock]
#    --------------------- ------------------  7/13 [filelock]
#    --------------------- ------------------  7/13 [filelock]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
#    ------------------------ ---------------  8/13 [torch]
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Jagdish singh\\OneDrive\\Desktop\\NLP\\nlp_env\\Lib\\site-packages\\torch\\autograd\\__init__.py'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# NLP task sentence Similarity

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Load pre-trained SBERT model
model = SentenceTransformer("all-MiniLM-L6-v2")

def compute_similarity(sentence1, sentence2):
    # Encode sentences into embeddings
    embedding1 = model.encode(sentence1)
    embedding2 = model.encode(sentence2)

    # Compute cosine similarity
    similarity_score = cosine_similarity([embedding1], [embedding2])[0][0]

    return similarity_score

# Example sentences
sentence1 = "A dog is running in the park ."
sentence2 = "A pup is playing in the park."

# Compute similarity
similarity = compute_similarity(sentence1, sentence2)

print(f"Sentence Similarity Score (SBERT): {similarity:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       2 from sklearn.metrics.pairwise import cosine_similarity
#       3
#       4 # Load pre-trained SBERT model
#
# ModuleNotFoundError: No module named 'sentence_transformers'

# %%
# Load pre-trained SBERT model
model = SentenceTransformer("all-MiniLM-L6-v2")

# Compute SBERT sentence embedding
sentence = "The dog runs fast"
embedding = model.encode(sentence)

print("Sentence Embedding (SBERT):", embedding[:5])  # Print first 5 values
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       2
#       3 # Load pre-trained SBERT model
#       4 model = SentenceTransformer("all-MiniLM-L6-v2")
#
# ModuleNotFoundError: No module named 'sentence_transformers'
