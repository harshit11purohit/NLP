# %% [markdown]
# ## Python Built-in Function - Count Words

# %%
text = "Natural Language Processing (NLP) is a fascinating field!"
words = text.split()
word_count = len(words)
print("Word Count:", word_count)
# Out:
# Word Count: 8

# %%
count=0
for word in words:
    count=count+1
print(count)
# Out:
# 8

# %% [markdown]
# ## Regex - Handle Punctuation and Count Words

# %%
import re

def count_words(text):
    words = re.findall(r'\b\w+\b', text)
    return len(words)

text = "Hello, world! Welcome to NLP()  !! ."
print("Word Count:", count_words(text))
# Out:
# Word Count: 5

# %% [markdown]
# ## NLTK - Python

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Jagdish
# [nltk_data]     singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk import word_tokenize,sent_tokenize

def count_words_nltk(text):
    words = word_tokenize(text)
    return len(words)

text = "Let's explore NLP with Python!"
print("Word Count:", count_words_nltk(text))
# Out:
# Word Count: 7

# %%
text1 = " heelo guys ... i am best ... i am the king .. i am good men "

def count_sentences(text):
    sentences = sent_tokenize(text)
    print("Extracted Sentences:", sentences)
    return len(sentences)

total_sentences = count_sentences(text1)
print("Total Sentence Count:", total_sentences)
# Out:
# Extracted Sentences: [' heelo guys ... i am best ... i am the king .. i am good men']
# Total Sentence Count: 1

# %%
nltk.download('punkt')
text1=" heelo guys ... i am best ... i am the king .. i am good men "
def count_sentences(text):
    words=sent_tokenize(text)
    return len(words)

print(count_sentences(text1))
# Out:
# 1
# [nltk_data] Downloading package punkt to C:\Users\Jagdish
# [nltk_data]     singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk
from nltk.tokenize import sent_tokenize

# Capitalizing the start of each thought helps the tokenizer detect the boundary
text2 = " heelo guys ... I am best ... I am the king .. I am good men "

print(len(sent_tokenize(text2)))
# Out:
# 4

# %%
import nltk
from nltk.tokenize import sent_tokenize

# Ensure the punctuation model is downloaded
nltk.download('punkt')

text1 = " heelo guys. i am best .i am the king . i am good men "

def count_sentences(text):
    words = sent_tokenize(text)
    return len(words)

# Wrap the function call in a print statement to display the output
print(count_sentences(text1))
# Out:
# 3
# [nltk_data] Downloading package punkt to C:\Users\Jagdish
# [nltk_data]     singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Spacy

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def count_words_spacy(text):
    doc = nlp(text)
    words = [token.text for token in doc if not token.is_punct]
    print(doc)
    return len(words)
text = "NLP is amazing, isn't it?"
print("Word Count:", count_words_spacy(text))
# Out:
# NLP is amazing, isn't it?
# Word Count: 6

# %%
def count_words_spacy(text):
    doc = nlp(text)
    print(doc)
    return len(doc)

text = "NLP is amazing, isn't it?"
print("Word Count:", count_words_spacy(text))
# Out:
# NLP is amazing, isn't it?
# Word Count: 8

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
text = "NLP is amazing, isn't it?"

def count_tokens_spacy(text):
    doc = nlp(text)
    print("Tokens parsed:", [token.text for token in doc])
    return len(doc)

def count_words_spacy(text):
    doc = nlp(text)
    words = [token.text for token in doc if not token.is_punct]
    print("Words parsed :", words)
    return len(words)

print("Approach 1 (Token Count):", count_tokens_spacy(text))
print("-" * 50)
print("Approach 2 (Word Count) :", count_words_spacy(text))
# Out:
# Tokens parsed: ['NLP', 'is', 'amazing', ',', 'is', "n't", 'it', '?']
# Approach 1 (Token Count): 8
# --------------------------------------------------
# Words parsed : ['NLP', 'is', 'amazing', 'is', "n't", 'it']
# Approach 2 (Word Count) : 6

# %% [markdown]
# ## Counter

# %%
from collections import Counter

def word_frequency(text):
    words = text.lower().split()
    return Counter(words)

text = "NLP is fun. NLP is powerful. NLP is the future."
print("Word Frequencies:", word_frequency(text))
# Out:
# Word Frequencies: Counter({'nlp': 3, 'is': 3, 'fun.': 1, 'powerful.': 1, 'the': 1, 'future.': 1})

# %%
text1 = "NLP is fun. NLP is powerful. NLP is the future."
def word_freq(text):
    doc=word_tokenize(text)
    return Counter(doc)
word_freq(text1)
# Out:
# Counter({'NLP': 3,
#          'is': 3,
#          '.': 3,
#          'fun': 1,
#          'powerful': 1,
#          'the': 1,
#          'future': 1})

# %%
from collections import Counter
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')

text1 = "NLP is fun. NLP is powerful. NLP is the future."

def word_freq(text):
    raw_tokens = word_tokenize(text)
    #clean_words = [token.lower() for token in raw_tokens if token.isalnum()]
    return Counter(raw_tokens)

print(word_freq(text1))
# Out:
# Counter({'NLP': 3, 'is': 3, '.': 3, 'fun': 1, 'powerful': 1, 'the': 1, 'future': 1})
# [nltk_data] Downloading package punkt to C:\Users\Jagdish
# [nltk_data]     singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## NLP Task 1 - Short vs Long sentences

# %%
from nltk.tokenize import sent_tokenize

def categorize_sentences(text):
    sentences = sent_tokenize(text)
    print(sentences)
    categorized = {"short": [], "long": []}

    for sentence in sentences:
        word_count = len(word_tokenize(sentence))
        if word_count < 5:
            categorized["short"].append(sentence)
        else:
            categorized["long"].append(sentence)

    return categorized

# %%
text = "Hello! NLP is fun. Let's learn NLP together. It helps in many fields."
categories = categorize_sentences(text)
print("Short Sentences:", categories["short"])
print("Long Sentences:", categories["long"])
# Out:
# ['Hello!', 'NLP is fun.', "Let's learn NLP together.", 'It helps in many fields.']
# Short Sentences: ['Hello!', 'NLP is fun.']
# Long Sentences: ["Let's learn NLP together.", 'It helps in many fields.']

# %%
def categorize_sentences(text):
    sentences = sent_tokenize(text)
    print(sentences)
    short= [ ]
    long=[ ]

    for sentence in sentences:
        word_count = len(word_tokenize(sentence))
        if word_count < 5:
            short.append(sentence)
        else:
            long.append(sentence)

    print(short)
    print(long)

text = "Hello! NLP is fun. Let's learn NLP together. It helps in many fields."
categorize_sentences(text)
# Out:
# ['Hello!', 'NLP is fun.', "Let's learn NLP together.", 'It helps in many fields.']
# ['Hello!', 'NLP is fun.']
# ["Let's learn NLP together.", 'It helps in many fields.']

# %%
text = "Hello! NLP is fun. Let's learn NLP together. It helps in many fields."

def categorize_sentences(text):
    sentences = sent_tokenize(text)
    print("All Sentences:", sentences)
    
    short = []
    long = []

    for sentence in sentences:
        # Fixed: count only alphanumeric words to keep word counts accurate
        word_count = len([w for w in word_tokenize(sentence) if w.isalnum()])
        
        # Word-count threshold comparison (less than 5 words)
        if word_count < 5:
            short.append(sentence)
        else:
            long.append(sentence)

    print("Short Sentences (< 5 words):", short)
    print("Long Sentences (>= 5 words):", long)
    
    # Minimal Change: return the grouped lists as a tuple
    return short, long

# Execute the pipeline
categorize_sentences(text)

# %% [markdown]
# ## NLP Task 2 - Rule based Sentiment Analysis

# %%
import time

positive_words = {"happy", "good", "great", "excellent", "love", "amazing"}
negative_words = {"sad", "bad", "terrible", "hate", "awful", "worst"}

def sentiment_analysis(text):
    start_time = time.time()
    
    # Initialize counters inside the function scope
    pos_count = 0
    neg_count = 0
    
    words = text.lower().split()
    for word in words:
        if word in positive_words:
            pos_count += 1
        elif word in negative_words:
            neg_count += 1

    sentiment = "Positive Sentiment" if pos_count > neg_count else "Negative Sentiment" if neg_count > pos_count else "Neutral Sentiment"

    end_time = time.time()
    execution_time = end_time - start_time

    return sentiment, execution_time

text = """
I'm happy you're the President, and thank you for bringing me home.
I have never been so proud to be an American citizen. Thank you, Mr. President.
"""
sentiment, exec_time = sentiment_analysis(text)
print("Sentiment:", sentiment)
print("Execution Time: {:.6f} seconds".format(exec_time))
# Out:
# Sentiment: Positive Sentiment
# Execution Time: 0.000013 seconds

# %%
import time
from nltk.tokenize import word_tokenize, sent_tokenize

positive_words = {"happy", "good", "great", "excellent", "love", "amazing"}
negative_words = {"sad", "bad", "terrible", "hate", "awful", "worst"}

def sentiment_analysis(text):
    start_time = time.time()
    
    sentences = sent_tokenize(text)
    
    pos_count = 0
    neg_count = 0
    
    for sentence in sentences:
        words = word_tokenize(sentence.lower())
        pos_count += sum(1 for word in words if word in positive_words )
        neg_count += sum(1 for word in words if word in negative_words )

    if pos_count > neg_count:
        sentiment = "Positive Sentiment"
    elif neg_count > pos_count:
        sentiment = "Negative Sentiment"
    else:
        sentiment = "Neutral Sentiment"

    end_time = time.time()
    execution_time = end_time - start_time

    return sentiment, execution_time

text = """
I'm happy you're the President, and thank you for bringing me home.
I have never been so proud to be an American citizen. Thank you, Mr. President.
"""
sentiment, exec_time = sentiment_analysis(text)
print("Sentiment:", sentiment)
print("Execution Time: {:.6f} seconds".format(exec_time))
# Out:
# Sentiment: Positive Sentiment
# Execution Time: 0.000458 seconds

# %%
import time
from nltk.tokenize import word_tokenize, sent_tokenize

positive_words = {"happy", "good", "great", "excellent", "love", "amazing"}
negative_words = {"sad", "bad", "terrible", "hate", "awful", "worst"}

def sentiment_analysis(text):
    start_time = time.time()
    
    sentences = sent_tokenize(text)
    
    pos_count = 0
    neg_count = 0
    
    for sentence in sentences:
        words = word_tokenize(sentence.lower())
        for word in words:
         if word in positive_words:
            pos_count += 1
         elif word in negative_words:
            neg_count += 1

    if pos_count > neg_count:
        sentiment = "Positive Sentiment"
    elif neg_count > pos_count:
        sentiment = "Negative Sentiment"
    else:
        sentiment = "Neutral Sentiment"

    end_time = time.time()
    execution_time = end_time - start_time

    return sentiment, execution_time

text = """
I'm happy you're the President, and thank you for bringing me home.
I have never been so proud to be an American citizen. Thank you, Mr. President.
"""
sentiment, exec_time = sentiment_analysis(text)
print("Sentiment:", sentiment)
print("Execution Time: {:.6f} seconds".format(exec_time))
# Out:
# Sentiment: Positive Sentiment
# Execution Time: 0.003891 seconds

# %%
text=" i am very sad happy "
sentiment_analysis(text)
# Out:
# ('Neutral Sentiment', 0.0001239776611328125)
