# %% [markdown]
# ## Using NLTK

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('punkt_tab')

text = "Hello world! NLP is amazing. Let's tokenize this sentence."

# Word Tokenization
print("Word Tokens:", word_tokenize(text))

# Sentence Tokenization
print("Sentence Tokens:", sent_tokenize(text))
# Out:
# Word Tokens: ['Hello', 'world', '!', 'NLP', 'is', 'amazing', '.', 'Let', "'s", 'tokenize', 'this', 'sentence', '.']
# Sentence Tokens: ['Hello world!', 'NLP is amazing.', "Let's tokenize this sentence."]
# [nltk_data] Downloading package punkt_tab to C:\Users\Jagdish
# [nltk_data]     singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ## Using Spacy

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

doc = nlp(text)
print("Word Tokens:", [token.text for token in doc])
print("Sentence Tokens:", [sent.text for sent in doc.sents])
# Out:
# Word Tokens: ['Hello', 'world', '!', 'NLP', 'is', 'amazing', '.', 'Let', "'s", 'tokenize', 'this', 'sentence', '.']
# Sentence Tokens: ['Hello world!', 'NLP is amazing.', "Let's tokenize this sentence."]

# %% [markdown]
# ## NLP Tasks

# %% [markdown]
# ## Basic Word Count & Frequency Distribution

# %%
from collections import Counter


text = "Hello world! NLP is amazing. Let's tokenize this sentence."

words = word_tokenize(text.lower())
word_freq = Counter(words)
print("Total Word Count:", len(words))
print("Word Frequency Distribution:", word_freq.most_common(5))
print(word_freq)
# Out:
# Total Word Count: 13
# Word Frequency Distribution: [('.', 2), ('hello', 1), ('world', 1), ('!', 1), ('nlp', 1)]
# Counter({'.': 2, 'hello': 1, 'world': 1, '!': 1, 'nlp': 1, 'is': 1, 'amazing': 1, 'let': 1, "'s": 1, 'tokenize': 1, 'this': 1, 'sentence': 1})

# %% [markdown]
# ### Stopwords removal with frequency analysis

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Jagdish
# [nltk_data]     singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word not in stop_words]
filtered_freq = Counter(filtered_words)

print("Filtered Word Frequency Distribution:", filtered_freq.most_common(5))
# Out:
# Filtered Word Frequency Distribution: [('.', 2), ('hello', 1), ('world', 1), ('!', 1), ('nlp', 1)]

# %% [markdown]
# ### NER with Context Analysis

# %%
import spacy
from collections import Counter

nlp = spacy.load("en_core_web_sm")  # Load spaCy model
text = "Apple is looking at buying U.K. startup for $1 billion."
doc = nlp(text) 


entity_freq = Counter([ent.text for ent in doc.ents])
for ent, freq in entity_freq.most_common():
    print(f"Entity: {ent}, Count: {freq}, Label: {nlp(ent)[0].ent_type_}")
# Out:
# Entity: Apple, Count: 1, Label: ORG
# Entity: U.K., Count: 1, Label: GPE
# Entity: $1 billion, Count: 1, Label: MONEY

# %%
nlp = spacy.load("en_core_web_sm")
text = "Apple is looking at buying U.K. startup for $1 billion."
doc = nlp(text)

# Initialize an empty Counter
entity_freq = Counter()

# Loop through the entities directly
for ent in doc.ents:
    # Use a clean tuple of (Text, Label) as the dictionary key
    entity_freq[(ent.text, ent.label_)] += 1

print(doc.ents)
# Print the results cleanly
for (ent_text, ent_label), freq in entity_freq.most_common():
    print(f"Entity: {ent_text} | Label: {ent_label} | Count: {freq}")
# Out:
# (Apple, U.K., $1 billion)
# Entity: Apple | Label: ORG | Count: 1
# Entity: U.K. | Label: GPE | Count: 1
# Entity: $1 billion | Label: MONEY | Count: 1

# %% [markdown]
# ### N-Grams with frequency analysis

# %%
from nltk.util import ngrams
from nltk.tokenize import word_tokenize

text = """
The field of natural language processing is a subfield of computer science.
Natural language processing is heavily based on machine learning algorithms.
"""


words = word_tokenize(text.lower())

bigrams = list(ngrams(words, 2))
trigrams = list(ngrams(words, 3))
bigram_freq = Counter(bigrams)
trigram_freq = Counter(trigrams)
print("Most Common Bigrams:", bigram_freq.most_common(5))
print("Most Common Trigrams:", trigram_freq.most_common(5))
# Out:
# Most Common Bigrams: [(('natural', 'language'), 2), (('language', 'processing'), 2), (('processing', 'is'), 2), (('the', 'field'), 1), (('field', 'of'), 1)]
# Most Common Trigrams: [(('natural', 'language', 'processing'), 2), (('language', 'processing', 'is'), 2), (('the', 'field', 'of'), 1), (('field', 'of', 'natural'), 1), (('of', 'natural', 'language'), 1)]

# %% [markdown]
# ### Keyword Extraction using TF-IDF with Tokenization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform([text])
feature_array = vectorizer.get_feature_names_out()
importance = X.toarray().flatten()
important_words = sorted(zip(feature_array, importance), key=lambda x: x[1], reverse=True)[:5]
print("Top Keywords:", [word for word, _ in important_words])
# Out:
# Top Keywords: ['is', 'language', 'natural', 'of', 'processing']

# %%
importance
# Out:
# array([0.1796053, 0.1796053, 0.1796053, 0.1796053, 0.1796053, 0.3592106,
#        0.3592106, 0.1796053, 0.1796053, 0.3592106, 0.3592106, 0.1796053,
#        0.3592106, 0.1796053, 0.1796053, 0.1796053])

# %%
feature_array
# Out:
# array(['algorithms', 'based', 'computer', 'field', 'heavily', 'is',
#        'language', 'learning', 'machine', 'natural', 'of', 'on',
#        'processing', 'science', 'subfield', 'the'], dtype=object)

# %% [markdown]
# ### POS Tagging

# %%
for token in doc:
    print(f"Token: {token.text}, POS: {token.pos_}")
# Out:
# Token: Apple, POS: PROPN
# Token: is, POS: AUX
# Token: looking, POS: VERB
# Token: at, POS: ADP
# Token: buying, POS: VERB
# Token: U.K., POS: PROPN
# Token: startup, POS: VERB
# Token: for, POS: ADP
# Token: $, POS: SYM
# Token: 1, POS: NUM
# Token: billion, POS: NUM
# Token: ., POS: PUNCT

# %% [markdown]
# ### Sentence Similarity

# %%
from sklearn.feature_extraction.text import CountVectorizer

sentences = ["I love NLP",
             "NLP is great for text processing", 
             "Machine learning is amazing"
             ]

vectorizer = CountVectorizer()

X = vectorizer.fit_transform(sentences)

print("Sentence Similarity Matrix:")
print((X * X.T).toarray())
# Out:
# Sentence Similarity Matrix:
# [[2 1 0]
#  [1 6 1]
#  [0 1 4]]

# %% [markdown]
# ### Text Summarization

# %%
len(filtered_freq)
# Out:
# 10

# %%
sentences = """I love NLP ,NLP is great for text processing , Machine learning is amazing"""
             
doc=nlp(sentences)

# %%
sentence_scores = {}

sentences = """I love NLP ,NLP is great for text processing , Machine learning is amazing"""
             
doc=nlp(sentences) 
for sent in doc.sents:
    for word in word_tokenize(sent.text.lower()):
        if word in filtered_freq:
            sentence_scores[sent.text] = sentence_scores.get(sent.text, 0) + filtered_freq[word]



sorted_sentences = sorted(sentence_scores, key=sentence_scores.get, reverse=True)
summary = " ".join(sorted_sentences[:2])
print("Summary:", summary)
# Out:
# Summary: I love NLP ,NLP is great for text processing , Machine learning is amazing

# %%
import spacy
from collections import Counter
from nltk.tokenize import word_tokenize

nlp = spacy.load("en_core_web_sm")

text = "Natural language processing is an exciting subfield of artificial intelligence. Machine learning models can automatically extract insights from massive volumes of unstructured text."

doc = nlp(text)
words = [word.text.lower() for word in doc if not word.is_stop and not word.is_punct]
filtered_freq = Counter(words)

sentence_scores = {}

for sent in doc.sents:
    for word in word_tokenize(sent.text.lower()):
        if word in filtered_freq:
            sentence_scores[sent.text] = sentence_scores.get(sent.text, 0) + filtered_freq[word]

sorted_sentences = sorted(sentence_scores, key=sentence_scores.get, reverse=True)
summary = " ".join(sorted_sentences[:2])
print("Summary:", summary)
# Out:
# Summary: Machine learning models can automatically extract insights from massive volumes of unstructured text. Natural language processing is an exciting subfield of artificial intelligence.

# %%
import spacy
import nltk
from nltk.tokenize import word_tokenize
from collections import Counter

# Download required NLTK tokenizer
nltk.download('punkt')

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Input text
text = """Natural Language Processing (NLP) is a field of AI that enables machines to understand human language.
It is used in chatbots, sentiment analysis, and language translation.
One of the key challenges in NLP is understanding context and ambiguity in sentences.
Deep learning models like transformers have significantly improved NLP applications."""

# Process text with spaCy
doc = nlp(text)

# Tokenize words and compute frequency
words = [word.lower() for word in word_tokenize(text) if word.isalnum()]
filtered_freq = Counter(words)

# Compute sentence scores
sentence_scores = {}
for sent in doc.sents:
    for word in word_tokenize(sent.text.lower()):
        if word in filtered_freq:
            sentence_scores[sent.text] = sentence_scores.get(sent.text, 0) + filtered_freq[word]

# Sort sentences by score
sorted_sentences = sorted(sentence_scores, key=sentence_scores.get, reverse=True)

# Select top-ranked sentences for summary
summary = " ".join(sorted_sentences[:2])

# Print summary
print("Summary:", summary)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Jagdish
# [nltk_data]     singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Summary: Natural Language Processing (NLP) is a field of AI that enables machines to understand human language.
#  One of the key challenges in NLP is understanding context and ambiguity in sentences.
